# %% [markdown]
# <a href="https://colab.research.google.com/github/Juancbr99/Altura_Peso/blob/main/Altura_Peso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
datos = pd.read_csv("Altura_Peso.csv")

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Altura  30 non-null     float64
#  1    peso   30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes

# %%
datos.head()
# Out:
#    Altura   peso
# 0    1.75      68
# 1    1.80      71
# 2    1.69      65
# 3    1.65      63
# 4    1.68      68

# %%
datos.describe
# Out:
#           Altura      peso
# count  30.000000  30.000000
# mean    1.666333  65.333333
# std     0.110998  10.911346
# min     1.480000  49.000000
# 25%     1.582500  59.000000
# 50%     1.675000  64.500000
# 75%     1.750000  70.750000
# max     1.890000  95.000000

# %%
print(datos.columns)
# Out:
# Index(['Altura', ' peso '], dtype='object')

# %%
import seaborn as sb
sb.scatterplot(x="Altura", y=" peso ", data=datos, hue=" peso ", palette="coolwarm")
# Out:
# <Axes: xlabel='Altura', ylabel=' peso '>

# %%
x = datos["Altura"]
y = datos[" peso "]

# %%
x
# Out:
# 0     1.75
# 1     1.80
# 2     1.69
# 3     1.65
# 4     1.68
# 5     1.54
# 6     1.72
# 7     1.75
# 8     1.59
# 9     1.61
# 10    1.85
# 11    1.55
# 12    1.68
# 13    1.72
# 14    1.49
# 15    1.66
# 16    1.76
# 17    1.81
# 18    1.57
# 19    1.48
# 20    1.69
# 21    1.52
# 22    1.89
# 23    1.77
# 24    1.58
# 25    1.64
# 26    1.79
# 27    1.67
# 28    1.49
# 29    1.60
# Name: Altura, dtype: float64

# %%
y
# Out:
# 0     68
# 1     71
# 2     65
# 3     63
# 4     68
# 5     51
# 6     55
# 7     64
# 8     85
# 9     49
# 10    70
# 11    56
# 12    60
# 13    59
# 14    53
# 15    67
# 16    76
# 17    79
# 18    62
# 19    50
# 20    65
# 21    59
# 22    95
# 23    69
# 24    62
# 25    71
# 26    82
# 27    74
# 28    51
# 29    61
# Name:  peso , dtype: int64

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
x.values
# Out:
# array([1.75, 1.8 , 1.69, 1.65, 1.68, 1.54, 1.72, 1.75, 1.59, 1.61, 1.85,
#        1.55, 1.68, 1.72, 1.49, 1.66, 1.76, 1.81, 1.57, 1.48, 1.69, 1.52,
#        1.89, 1.77, 1.58, 1.64, 1.79, 1.67, 1.49, 1.6 ])

# %%
y.values
# Out:
# array([68, 71, 65, 63, 68, 51, 55, 64, 85, 49, 70, 56, 60, 59, 53, 67, 76,
#        79, 62, 50, 65, 59, 95, 69, 62, 71, 82, 74, 51, 61])

# %%
x.values.reshape(-1,1)
# Out:
# array([[1.75],
#        [1.8 ],
#        [1.69],
#        [1.65],
#        [1.68],
#        [1.54],
#        [1.72],
#        [1.75],
#        [1.59],
#        [1.61],
#        [1.85],
#        [1.55],
#        [1.68],
#        [1.72],
#        [1.49],
#        [1.66],
#        [1.76],
#        [1.81],
#        [1.57],
#        [1.48],
#        [1.69],
#        [1.52],
#        [1.89],
#        [1.77],
#        [1.58],
#        [1.64],
#        [1.79],
#        [1.67],
#        [1.49],
#        [1.6 ]])

# %%
y.values.reshape(-1,1)
# Out:
# array([[68],
#        [71],
#        [65],
#        [63],
#        [68],
#        [51],
#        [55],
#        [64],
#        [85],
#        [49],
#        [70],
#        [56],
#        [60],
#        [59],
#        [53],
#        [67],
#        [76],
#        [79],
#        [62],
#        [50],
#        [65],
#        [59],
#        [95],
#        [69],
#        [62],
#        [71],
#        [82],
#        [74],
#        [51],
#        [61]])

# %%
x_procesada = x.values.reshape(-1,1)
y_procesada = y.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
modelo = LinearRegression()

# %%
modelo.fit(x_procesada, y_procesada)
# Out:
# LinearRegression()

# %%
modelo.predict([[1.99]])
# Out:
# array([[87.46087752]])

# %%
modelo.predict([[1.65]])
# Out:
# array([[64.21670134]])

# %%
modelo.predict([[2.01]])
# Out:
# array([[88.828182]])

# %%
modelo.score(x_procesada, y_procesada)
# Out:
# 0.48366514944087213

# %%
Altura = float(input())
prediccion = modelo.predict([[Altura]])
print(f"una persona que mide {Altura} metros, podria estar pesando {prediccion} kilos")
# Out:
# 2.05
# una persona que mide 2.05 metros, podria estar pesando [[91.56279096]] kilos

# %%
Altura = float(input())
prediccion = modelo.predict([[Altura]])
print(f"una persona que mide {Altura} metros, podria estar pesando {prediccion} kilos")
# Out:
# 2.18
# una persona que mide 2.18 metros, podria estar pesando [[100.45027008]] kilos

# %%
Altura = float(input())
prediccion = modelo.predict([[Altura]])
print(f"una persona que mide {Altura} metros, podria estar pesando {prediccion} kilos")
# Out:
# 1.39
# una persona que mide 1.39 metros, podria estar pesando [[46.44174309]] kilos
